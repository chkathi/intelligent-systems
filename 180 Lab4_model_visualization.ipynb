# %% [markdown]
# #### CSC 180 Intelligent Systems
#
# #### Dr. Haiquan Chen, Dept of Computer Scicence
#
# #### California State University, Sacramento

# %% [markdown]
# ## Lab 4: Model Performance Visualization

# %% [markdown]
# ### Helpful Functions for Tensorflow
#
# The following functions will be used with TensorFlow to help preprocess the data.  They allow you to build the feature vector for a neural network.
#
# * Predictors/Inputs
#     * Fill any missing inputs with the median for that column.  Use **missing_median**.
#     * Encode textual/categorical values with **encode_text_dummy**.
#     * Encode numeric values with **encode_numeric_zscore**.
# * Output
#     * Discard rows with missing outputs.
#     * Encode textual/categorical values with **encode_text_index**.
#     * Do not encode output numeric values.
# * Produce final feature vectors (x) and expected output (y) with **to_xy**.

# %%
from collections.abc import Sequence
from sklearn import preprocessing
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import shutil
import os


# Encode text values to dummy variables(i.e. [1,0,0],[0,1,0],[0,0,1] for red,green,blue)
def encode_text_dummy(df, name):
    dummies = pd.get_dummies(df[name])
    for x in dummies.columns:
        dummy_name = "{}-{}".format(name, x)
        df[dummy_name] = dummies[x]
    df.drop(name, axis=1, inplace=True)



# Encode text values to indexes(i.e. [1],[2],[3] for red,green,blue).
def encode_text_index(df, name):
    le = preprocessing.LabelEncoder()
    df[name] = le.fit_transform(df[name])
    return le.classes_


# Encode a numeric column as zscores
def encode_numeric_zscore(df, name, mean=None, sd=None):
    if mean is None:
        mean = df[name].mean()

    if sd is None:
        sd = df[name].std()

    df[name] = (df[name] - mean) / sd


# Convert all missing values in the specified column to the median
def missing_median(df, name):
    med = df[name].median()
    df[name] = df[name].fillna(med)


# Convert all missing values in the specified column to the default
def missing_default(df, name, default_value):
    df[name] = df[name].fillna(default_value)


# Convert a Pandas dataframe to the x,y inputs that TensorFlow needs
def to_xy(df, target):
    result = []
    for x in df.columns:
        if x != target:
            result.append(x)
    # find out the type of the target column. 
    target_type = df[target].dtypes
    target_type = target_type[0] if isinstance(target_type, Sequence) else target_type
    # Encode to int for classification, float otherwise. TensorFlow likes 32 bits.
    if target_type in (np.int64, np.int32):
        # Classification
        dummies = pd.get_dummies(df[target])
        return df[result].values.astype(np.float32), dummies.values.astype(np.float32)
    else:
        # Regression
        return df[result].values.astype(np.float32), df[target].values.astype(np.float32)

# Nicely formatted time string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)


# Regression chart.
def chart_regression(pred,y,sort=True):
    t = pd.DataFrame({'pred' : pred, 'y' : y.flatten()})
    if sort:
        t.sort_values(by=['y'],inplace=True)
    a = plt.plot(t['y'].tolist(),label='expected')
    b = plt.plot(t['pred'].tolist(),label='prediction')
    plt.ylabel('output')
    plt.legend()
    plt.show()

# Remove all rows where the specified column is +/- sd standard deviations
def remove_outliers(df, name, sd):
    drop_rows = df.index[(np.abs(df[name] - df[name].mean()) >= (sd * df[name].std()))]
    df.drop(drop_rows, axis=0, inplace=True)


# Encode a column to a range between normalized_low and normalized_high.
def encode_numeric_range(df, name, normalized_low=-1, normalized_high=1,
                         data_low=None, data_high=None):
    if data_low is None:
        data_low = min(df[name])
        data_high = max(df[name])

    df[name] = ((df[name] - data_low) / (data_high - data_low)) \
               * (normalized_high - normalized_low) + normalized_low

# %% [markdown]
# # Metrics:
#
# For any type of classification neural network:
#
# * **Accuracy**
# * **Precision**
# * **Recall**
# * **F1 Score**
# * **Log Loss**
# * **Confusion Matrix**
# * **ROC Curve**
#
# For regression neural networks:
# * **RMSE**
# * **R2 Score**
# * **Lift Chart**
#
# Check Sklearn API here http://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics
#
# The code used to produce Confusion matrix and ROC curve is shown here:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Plot a confusion matrix.
# cm is the confusion matrix, names are the names of the classes.
def plot_confusion_matrix(cm, names, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(names))
    plt.xticks(tick_marks, names, rotation=45)
    plt.yticks(tick_marks, names)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    

# Plot an ROC. pred - the predictions, y - the expected output.
def plot_roc(pred,y):
    fpr, tpr, thresholds = roc_curve(y, pred)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC)')
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# # Visualizing binary classification models
#
#
# Binary classification is used to create a model that classifies between only two classes.  These two classes are often called "positive" and "negative".

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np
from sklearn import metrics
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint

# Set the desired TensorFlow output level for this example
# tf.logging.set_verbosity(tf.logging.ERROR)

path = "./data/"
    
filename = os.path.join(path,"wcbreast_wdbc.csv")    
df = pd.read_csv(filename,na_values=['NA','?'])
df
# Out:
#            id diagnosis  mean_radius  mean_texture  mean_perimeter  mean_area  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      mean_smoothness  mean_compactness  mean_concavity  mean_concave_points  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  worst_radius  worst_texture  worst_perimeter  worst_area  \
# 0    ...        25.380          17.33           184.60      2019.0
# 1    ...        24.990          23.41           158.80      1956.0
# 2    ...        23.570          25.53           152.50      1709.0
# 3    ...        14.910          26.50            98.87       567.7
# 4    ...        22.540          16.67           152.20      1575.0
# ..   ...           ...            ...              ...         ...
# 564  ...        25.450          26.40           166.10      2027.0
# 565  ...        23.690          38.25           155.00      1731.0
# 566  ...        18.980          34.12           126.70      1124.0
# 567  ...        25.740          39.42           184.60      1821.0
# 568  ...         9.456          30.37            59.16       268.6
#
#      worst_smoothness  worst_compactness  worst_concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst_concave_points  worst_symmetry  worst_fractal_dimension
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [569 rows x 32 columns]

# %%
# Encode feature vector
df.drop('id',axis=1,inplace=True)

diagnosis = encode_text_index(df,'diagnosis')

# Create x & y for training and testing
x, y = to_xy(df,'diagnosis')
    
# Split into train/test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %% [markdown]
# ### Important!! Avoid local optimum: Jump out of local optimum by using a loop to train a model multiple times!!

# %%
# Define ModelCheckpoint outside the loop
checkpointer = ModelCheckpoint(filepath="dnn/best_weights.hdf5", verbose=0, save_best_only=True) # save best model

# otherwise new model will override after each loop

for i in range(5):
    print(i)

    # Build network
    model = Sequential()
    model.add(Dense(20, input_dim=x.shape[1], activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(y.shape[1], activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam')

    monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, verbose=1, mode='auto')

    # add early stopping within the loop
    model.fit(x_train,y_train,validation_data=(x_test,y_test),callbacks=[monitor,checkpointer],verbose=2,epochs=100)


print('Training finished...Loading the best model')  
print()
model.load_weights('dnn/best_weights.hdf5') # load weights from best model

# Measure accuracy
pred = model.predict(x_test)
pred = np.argmax(pred,axis=1)

y_true = np.argmax(y_test,axis=1)

score = metrics.accuracy_score(y_true, pred)
print("Final accuracy: {}".format(score))
# Out:
# 0
# Epoch 1/100
# 14/14 - 1s - loss: 6.4429 - val_loss: 2.3833 - 1s/epoch - 105ms/step
# Epoch 2/100
# 14/14 - 0s - loss: 1.0455 - val_loss: 0.7020 - 114ms/epoch - 8ms/step
# Epoch 3/100
# 14/14 - 0s - loss: 0.6638 - val_loss: 0.6565 - 112ms/epoch - 8ms/step
# Epoch 4/100
# 14/14 - 0s - loss: 0.6314 - val_loss: 0.5931 - 107ms/epoch - 8ms/step
# Epoch 5/100
# 14/14 - 0s - loss: 0.5389 - val_loss: 0.4777 - 114ms/epoch - 8ms/step
# Epoch 6/100
# 14/14 - 0s - loss: 0.5125 - val_loss: 0.4602 - 151ms/epoch - 11ms/step
# Epoch 7/100
# 14/14 - 0s - loss: 0.4762 - val_loss: 0.4370 - 111ms/epoch - 8ms/step
# Epoch 8/100
# 14/14 - 0s - loss: 0.4784 - val_loss: 0.4405 - 129ms/epoch - 9ms/step
# Epoch 9/100
# 14/14 - 0s - loss: 0.4669 - val_loss: 0.4224 - 121ms/epoch - 9ms/step
# Epoch 10/100
# 14/14 - 0s - loss: 0.4603 - val_loss: 0.4209 - 158ms/epoch - 11ms/step
# Epoch 11/100
# 14/14 - 0s - loss: 0.4589 - val_loss: 0.4119 - 113ms/epoch - 8ms/step
# Epoch 12/100
# 14/14 - 0s - loss: 0.4521 - val_loss: 0.4089 - 105ms/epoch - 8ms/step
# Epoch 13/100
# 14/14 - 0s - loss: 0.4489 - val_loss: 0.4063 - 91ms/epoch - 7ms/step
# Epoch 14/100
# 14/14 - 0s - loss: 0.4471 - val_loss: 0.3955 - 95ms/epoch - 7ms/step
# Epoch 15/100
# 14/14 - 0s - loss: 0.4393 - val_loss: 0.3943 - 110ms/epoch - 8ms/step
# Epoch 16/100
# 14/14 - 0s - loss: 0.4399 - val_loss: 0.3902 - 105ms/epoch - 7ms/step
# Epoch 17/100
# 14/14 - 0s - loss: 0.4296 - val_loss: 0.3804 - 243ms/epoch - 17ms/step
# Epoch 18/100
# 14/14 - 0s - loss: 0.4245 - val_loss: 0.3825 - 69ms/epoch - 5ms/step
# Epoch 19/100
# 14/14 - 0s - loss: 0.4213 - val_loss: 0.3732 - 105ms/epoch - 8ms/step
# Epoch 20/100
# 14/14 - 0s - loss: 0.4148 - val_loss: 0.3672 - 89ms/epoch - 6ms/step
# Epoch 21/100
# 14/14 - 0s - loss: 0.4141 - val_loss: 0.3694 - 58ms/epoch - 4ms/step
# Epoch 22/100
# 14/14 - 0s - loss: 0.4086 - val_loss: 0.3562 - 85ms/epoch - 6ms/step
# Epoch 23/100
# 14/14 - 0s - loss: 0.4064 - val_loss: 0.3583 - 61ms/epoch - 4ms/step
# Epoch 24/100
# 14/14 - 0s - loss: 0.3985 - val_loss: 0.3489 - 88ms/epoch - 6ms/step
# Epoch 25/100
# 14/14 - 0s - loss: 0.3969 - val_loss: 0.3438 - 87ms/epoch - 6ms/step
# Epoch 26/100
# 14/14 - 0s - loss: 0.3928 - val_loss: 0.3390 - 93ms/epoch - 7ms/step
# Epoch 27/100
# 14/14 - 0s - loss: 0.3869 - val_loss: 0.3353 - 86ms/epoch - 6ms/step
# Epoch 28/100
# 14/14 - 0s - loss: 0.3887 - val_loss: 0.3438 - 59ms/epoch - 4ms/step
# Epoch 29/100
# 14/14 - 0s - loss: 0.3785 - val_loss: 0.3302 - 87ms/epoch - 6ms/step
# Epoch 30/100
# 14/14 - 0s - loss: 0.3883 - val_loss: 0.3473 - 60ms/epoch - 4ms/step
# Epoch 31/100
# 14/14 - 0s - loss: 0.3833 - val_loss: 0.3205 - 88ms/epoch - 6ms/step
# Epoch 32/100
# 14/14 - 0s - loss: 0.3691 - val_loss: 0.3270 - 59ms/epoch - 4ms/step
# Epoch 33/100
# 14/14 - 0s - loss: 0.3702 - val_loss: 0.3131 - 86ms/epoch - 6ms/step
# Epoch 34/100
# 14/14 - 0s - loss: 0.3634 - val_loss: 0.3140 - 59ms/epoch - 4ms/step
# Epoch 35/100
# 14/14 - 0s - loss: 0.3647 - val_loss: 0.3072 - 86ms/epoch - 6ms/step
# Epoch 36/100
# 14/14 - 0s - loss: 0.3581 - val_loss: 0.3000 - 87ms/epoch - 6ms/step
# Epoch 37/100
# 14/14 - 0s - loss: 0.3588 - val_loss: 0.3034 - 58ms/epoch - 4ms/step
# Epoch 38/100
# 14/14 - 0s - loss: 0.3552 - val_loss: 0.2995 - 86ms/epoch - 6ms/step
# Epoch 39/100
# 14/14 - 0s - loss: 0.3517 - val_loss: 0.2957 - 85ms/epoch - 6ms/step
# Epoch 40/100
# 14/14 - 0s - loss: 0.3519 - val_loss: 0.2899 - 89ms/epoch - 6ms/step
# Epoch 41/100
# 14/14 - 0s - loss: 0.3456 - val_loss: 0.2827 - 87ms/epoch - 6ms/step
# Epoch 42/100
# 14/14 - 0s - loss: 0.3465 - val_loss: 0.2798 - 87ms/epoch - 6ms/step
# Epoch 43/100
# 14/14 - 0s - loss: 0.3385 - val_loss: 0.2802 - 60ms/epoch - 4ms/step
# Epoch 44/100
# 14/14 - 0s - loss: 0.3460 - val_loss: 0.3176 - 62ms/epoch - 4ms/step
# Epoch 45/100
# 14/14 - 0s - loss: 0.3508 - val_loss: 0.2747 - 87ms/epoch - 6ms/step
# Epoch 46/100
# 14/14 - 0s - loss: 0.3491 - val_loss: 0.2666 - 89ms/epoch - 6ms/step
# Epoch 47/100
# 14/14 - 0s - loss: 0.3324 - val_loss: 0.2716 - 60ms/epoch - 4ms/step
# Epoch 48/100
# 14/14 - 0s - loss: 0.3267 - val_loss: 0.2642 - 88ms/epoch - 6ms/step
# Epoch 49/100
# 14/14 - 0s - loss: 0.3272 - val_loss: 0.2691 - 62ms/epoch - 4ms/step
# Epoch 50/100
# 14/14 - 0s - loss: 0.3225 - val_loss: 0.2606 - 90ms/epoch - 6ms/step
# Epoch 51/100
# 14/14 - 0s - loss: 0.3221 - val_loss: 0.2545 - 92ms/epoch - 7ms/step
# Epoch 52/100
# 14/14 - 0s - loss: 0.3244 - val_loss: 0.2523 - 86ms/epoch - 6ms/step
# Epoch 53/100
# 14/14 - 0s - loss: 0.3133 - val_loss: 0.2697 - 63ms/epoch - 5ms/step
# Epoch 54/100
# 14/14 - 0s - loss: 0.3230 - val_loss: 0.2475 - 93ms/epoch - 7ms/step
# Epoch 55/100
# 14/14 - 0s - loss: 0.3087 - val_loss: 0.2473 - 87ms/epoch - 6ms/step
# Epoch 56/100
# 14/14 - 0s - loss: 0.3081 - val_loss: 0.2512 - 63ms/epoch - 5ms/step
# Epoch 57/100
# 14/14 - 0s - loss: 0.3157 - val_loss: 0.2489 - 61ms/epoch - 4ms/step
# Epoch 58/100
# 14/14 - 0s - loss: 0.3094 - val_loss: 0.2471 - 89ms/epoch - 6ms/step
# Epoch 59/100
# 14/14 - 0s - loss: 0.3016 - val_loss: 0.2361 - 91ms/epoch - 7ms/step
# Epoch 60/100
# 14/14 - 0s - loss: 0.3047 - val_loss: 0.2330 - 85ms/epoch - 6ms/step
# Epoch 61/100
# 14/14 - 0s - loss: 0.3015 - val_loss: 0.2324 - 86ms/epoch - 6ms/step
# Epoch 62/100
# 14/14 - 0s - loss: 0.2959 - val_loss: 0.2408 - 58ms/epoch - 4ms/step
# Epoch 63/100
# 14/14 - 0s - loss: 0.2982 - val_loss: 0.2293 - 83ms/epoch - 6ms/step
# Epoch 64/100
# 14/14 - 0s - loss: 0.2940 - val_loss: 0.2282 - 86ms/epoch - 6ms/step
# Epoch 65/100
# 14/14 - 0s - loss: 0.3013 - val_loss: 0.2362 - 60ms/epoch - 4ms/step
# Epoch 66/100
# 14/14 - 0s - loss: 0.2959 - val_loss: 0.2457 - 56ms/epoch - 4ms/step
# Epoch 67/100
# 14/14 - 0s - loss: 0.2904 - val_loss: 0.2180 - 82ms/epoch - 6ms/step
# Epoch 68/100
# 14/14 - 0s - loss: 0.2875 - val_loss: 0.2218 - 59ms/epoch - 4ms/step
# Epoch 69/100
# 14/14 - 0s - loss: 0.2879 - val_loss: 0.2237 - 56ms/epoch - 4ms/step
# Epoch 70/100
# 14/14 - 0s - loss: 0.2974 - val_loss: 0.2133 - 83ms/epoch - 6ms/step
# Epoch 71/100
# 14/14 - 0s - loss: 0.2858 - val_loss: 0.2112 - 133ms/epoch - 9ms/step
# Epoch 72/100
# 14/14 - 0s - loss: 0.2803 - val_loss: 0.2091 - 86ms/epoch - 6ms/step
# Epoch 73/100
# 14/14 - 0s - loss: 0.2812 - val_loss: 0.2049 - 83ms/epoch - 6ms/step
# Epoch 74/100
# 14/14 - 0s - loss: 0.2888 - val_loss: 0.2115 - 58ms/epoch - 4ms/step
# Epoch 75/100
# 14/14 - 0s - loss: 0.2724 - val_loss: 0.2042 - 88ms/epoch - 6ms/step
# Epoch 76/100
# 14/14 - 0s - loss: 0.2772 - val_loss: 0.2061 - 60ms/epoch - 4ms/step
# Epoch 77/100
# 14/14 - 0s - loss: 0.2795 - val_loss: 0.2215 - 57ms/epoch - 4ms/step
# Epoch 78/100
# 14/14 - 0s - loss: 0.2712 - val_loss: 0.2017 - 83ms/epoch - 6ms/step
# Epoch 79/100
# 14/14 - 0s - loss: 0.2782 - val_loss: 0.1958 - 85ms/epoch - 6ms/step
# Epoch 80/100
# 14/14 - 0s - loss: 0.2749 - val_loss: 0.1999 - 60ms/epoch - 4ms/step
# Epoch 81/100
# 14/14 - 0s - loss: 0.2703 - val_loss: 0.1975 - 59ms/epoch - 4ms/step
# Epoch 82/100
# 14/14 - 0s - loss: 0.2705 - val_loss: 0.2050 - 59ms/epoch - 4ms/step
# Epoch 83/100
# 14/14 - 0s - loss: 0.2656 - val_loss: 0.1920 - 86ms/epoch - 6ms/step
# Epoch 84/100
# 14/14 - 0s - loss: 0.2642 - val_loss: 0.2119 - 60ms/epoch - 4ms/step
# Epoch 85/100
# 14/14 - 0s - loss: 0.2643 - val_loss: 0.1868 - 87ms/epoch - 6ms/step
# Epoch 86/100
# 14/14 - 0s - loss: 0.2603 - val_loss: 0.1901 - 57ms/epoch - 4ms/step
# Epoch 87/100
# 14/14 - 0s - loss: 0.2630 - val_loss: 0.1834 - 84ms/epoch - 6ms/step
# Epoch 88/100
# 14/14 - 0s - loss: 0.2604 - val_loss: 0.1848 - 58ms/epoch - 4ms/step
# Epoch 89/100
# 14/14 - 0s - loss: 0.2607 - val_loss: 0.2111 - 58ms/epoch - 4ms/step
# Epoch 90/100
# 14/14 - 0s - loss: 0.2596 - val_loss: 0.1803 - 86ms/epoch - 6ms/step
# Epoch 91/100
# 14/14 - 0s - loss: 0.2618 - val_loss: 0.1973 - 57ms/epoch - 4ms/step
# Epoch 92/100
# 14/14 - 0s - loss: 0.2643 - val_loss: 0.2408 - 58ms/epoch - 4ms/step
# Epoch 93/100
# 14/14 - 0s - loss: 0.2684 - val_loss: 0.2116 - 56ms/epoch - 4ms/step
# Epoch 94/100
# 14/14 - 0s - loss: 0.2630 - val_loss: 0.1830 - 58ms/epoch - 4ms/step
# Epoch 95/100
# 14/14 - 0s - loss: 0.2647 - val_loss: 0.1866 - 57ms/epoch - 4ms/step
# Epoch 95: early stopping
# 1
# Epoch 1/100
# 14/14 - 1s - loss: 32.2255 - val_loss: 2.5117 - 981ms/epoch - 70ms/step
# Epoch 2/100
# 14/14 - 0s - loss: 5.9619 - val_loss: 3.1444 - 58ms/epoch - 4ms/step
# Epoch 3/100
# 14/14 - 0s - loss: 3.0477 - val_loss: 2.8712 - 56ms/epoch - 4ms/step
# Epoch 4/100
# 14/14 - 0s - loss: 1.4619 - val_loss: 0.4082 - 59ms/epoch - 4ms/step
# Epoch 5/100
# 14/14 - 0s - loss: 0.8476 - val_loss: 0.7220 - 57ms/epoch - 4ms/step
# Epoch 6/100
# 14/14 - 0s - loss: 0.7752 - val_loss: 0.4474 - 59ms/epoch - 4ms/step
# Epoch 7/100
# 14/14 - 0s - loss: 0.6120 - val_loss: 0.4430 - 60ms/epoch - 4ms/step
# Epoch 8/100
# 14/14 - 0s - loss: 0.7303 - val_loss: 0.3803 - 58ms/epoch - 4ms/step
# Epoch 9/100
# 14/14 - 0s - loss: 0.6886 - val_loss: 0.5727 - 58ms/epoch - 4ms/step
# Epoch 10/100
# 14/14 - 0s - loss: 0.6104 - val_loss: 0.2941 - 57ms/epoch - 4ms/step
# Epoch 11/100
# 14/14 - 0s - loss: 0.5403 - val_loss: 0.3030 - 59ms/epoch - 4ms/step
# Epoch 12/100
# 14/14 - 0s - loss: 0.5213 - val_loss: 0.2670 - 57ms/epoch - 4ms/step
# Epoch 13/100
# 14/14 - 0s - loss: 0.5930 - val_loss: 0.3420 - 58ms/epoch - 4ms/step
# Epoch 14/100
# 14/14 - 0s - loss: 0.5505 - val_loss: 0.3198 - 58ms/epoch - 4ms/step
# Epoch 15/100
# 14/14 - 0s - loss: 0.4434 - val_loss: 0.2533 - 59ms/epoch - 4ms/step
# Epoch 16/100
# 14/14 - 0s - loss: 0.4896 - val_loss: 0.2650 - 56ms/epoch - 4ms/step
# Epoch 17/100
# 14/14 - 0s - loss: 0.4147 - val_loss: 0.2399 - 57ms/epoch - 4ms/step
# Epoch 18/100
# 14/14 - 0s - loss: 0.4132 - val_loss: 0.2170 - 56ms/epoch - 4ms/step
# Epoch 19/100
# 14/14 - 0s - loss: 0.3835 - val_loss: 0.1973 - 57ms/epoch - 4ms/step
# Epoch 20/100
# 14/14 - 0s - loss: 0.3738 - val_loss: 0.2092 - 58ms/epoch - 4ms/step
# Epoch 21/100
# 14/14 - 0s - loss: 0.3817 - val_loss: 0.1809 - 55ms/epoch - 4ms/step
# Epoch 22/100
# 14/14 - 0s - loss: 0.3695 - val_loss: 0.1779 - 87ms/epoch - 6ms/step
# Epoch 23/100
# 14/14 - 0s - loss: 0.3394 - val_loss: 0.1642 - 83ms/epoch - 6ms/step
# Epoch 24/100
# 14/14 - 0s - loss: 0.3092 - val_loss: 0.1797 - 57ms/epoch - 4ms/step
# Epoch 25/100
# 14/14 - 0s - loss: 0.3225 - val_loss: 0.2220 - 202ms/epoch - 14ms/step
# Epoch 26/100
# 14/14 - 0s - loss: 0.3759 - val_loss: 0.1513 - 88ms/epoch - 6ms/step
# Epoch 27/100
# 14/14 - 0s - loss: 0.3743 - val_loss: 0.2001 - 59ms/epoch - 4ms/step
# Epoch 28/100
# 14/14 - 0s - loss: 0.2933 - val_loss: 0.1399 - 82ms/epoch - 6ms/step
# Epoch 29/100
# 14/14 - 0s - loss: 0.2743 - val_loss: 0.1400 - 58ms/epoch - 4ms/step
# Epoch 30/100
# 14/14 - 0s - loss: 0.2730 - val_loss: 0.1330 - 83ms/epoch - 6ms/step
# Epoch 31/100
# 14/14 - 0s - loss: 0.2710 - val_loss: 0.1367 - 56ms/epoch - 4ms/step
# Epoch 32/100
# 14/14 - 0s - loss: 0.2607 - val_loss: 0.1558 - 56ms/epoch - 4ms/step
# Epoch 33/100
# 14/14 - 0s - loss: 0.2928 - val_loss: 0.1398 - 56ms/epoch - 4ms/step
# Epoch 34/100
# 14/14 - 0s - loss: 0.2868 - val_loss: 0.1233 - 83ms/epoch - 6ms/step
# Epoch 35/100
# 14/14 - 0s - loss: 0.2337 - val_loss: 0.1188 - 83ms/epoch - 6ms/step
# Epoch 36/100
# 14/14 - 0s - loss: 0.2450 - val_loss: 0.1500 - 56ms/epoch - 4ms/step
# Epoch 37/100
# 14/14 - 0s - loss: 0.2568 - val_loss: 0.1853 - 102ms/epoch - 7ms/step
# Epoch 38/100
# 14/14 - 0s - loss: 0.2650 - val_loss: 0.1185 - 86ms/epoch - 6ms/step
# Epoch 39/100
# 14/14 - 0s - loss: 0.2185 - val_loss: 0.1884 - 58ms/epoch - 4ms/step
# Epoch 40/100
# 14/14 - 0s - loss: 0.2774 - val_loss: 0.1308 - 57ms/epoch - 4ms/step
# Epoch 40: early stopping
# 2
# Epoch 1/100
# 14/14 - 1s - loss: 47.9010 - val_loss: 13.0260 - 948ms/epoch - 68ms/step
# Epoch 2/100
# 14/14 - 0s - loss: 4.2899 - val_loss: 3.8463 - 60ms/epoch - 4ms/step
# Epoch 3/100
# 14/14 - 0s - loss: 2.3703 - val_loss: 0.5296 - 59ms/epoch - 4ms/step
# Epoch 4/100
# 14/14 - 0s - loss: 1.4738 - val_loss: 0.4690 - 57ms/epoch - 4ms/step
# Epoch 5/100
# 14/14 - 0s - loss: 1.1627 - val_loss: 0.4925 - 59ms/epoch - 4ms/step
# Epoch 6/100
# 14/14 - 0s - loss: 0.9907 - val_loss: 0.3742 - 56ms/epoch - 4ms/step
# Epoch 7/100
# 14/14 - 0s - loss: 0.9149 - val_loss: 0.3557 - 57ms/epoch - 4ms/step
# Epoch 8/100
# 14/14 - 0s - loss: 0.8091 - val_loss: 0.3036 - 57ms/epoch - 4ms/step
# Epoch 9/100
# 14/14 - 0s - loss: 0.7720 - val_loss: 0.2533 - 57ms/epoch - 4ms/step
# Epoch 10/100
# 14/14 - 0s - loss: 0.6779 - val_loss: 0.2188 - 55ms/epoch - 4ms/step
# Epoch 11/100
# 14/14 - 0s - loss: 0.5766 - val_loss: 0.1941 - 57ms/epoch - 4ms/step
# Epoch 12/100
# 14/14 - 0s - loss: 0.5701 - val_loss: 0.2793 - 57ms/epoch - 4ms/step
# Epoch 13/100
# 14/14 - 0s - loss: 0.5132 - val_loss: 0.1871 - 58ms/epoch - 4ms/step
# Epoch 14/100
# 14/14 - 0s - loss: 0.4320 - val_loss: 0.1366 - 56ms/epoch - 4ms/step
# Epoch 15/100
# 14/14 - 0s - loss: 0.3915 - val_loss: 0.1198 - 58ms/epoch - 4ms/step
# Epoch 16/100
# 14/14 - 0s - loss: 0.3454 - val_loss: 0.1183 - 82ms/epoch - 6ms/step
# Epoch 17/100
# 14/14 - 0s - loss: 0.3280 - val_loss: 0.1063 - 85ms/epoch - 6ms/step
# Epoch 18/100
# 14/14 - 0s - loss: 0.3210 - val_loss: 0.1118 - 60ms/epoch - 4ms/step
# Epoch 19/100
# 14/14 - 0s - loss: 0.3016 - val_loss: 0.1388 - 60ms/epoch - 4ms/step
# Epoch 20/100
# 14/14 - 0s - loss: 0.2615 - val_loss: 0.2309 - 60ms/epoch - 4ms/step
# Epoch 21/100
# 14/14 - 0s - loss: 0.3846 - val_loss: 0.3294 - 59ms/epoch - 4ms/step
# Epoch 22/100
# 14/14 - 0s - loss: 0.3077 - val_loss: 0.1063 - 57ms/epoch - 4ms/step
# Epoch 22: early stopping
# 3
# Epoch 1/100
# 14/14 - 1s - loss: 95.6939 - val_loss: 62.9057 - 938ms/epoch - 67ms/step
# Epoch 2/100
# 14/14 - 0s - loss: 42.7691 - val_loss: 13.6778 - 57ms/epoch - 4ms/step
# Epoch 3/100
# 14/14 - 0s - loss: 3.8748 - val_loss: 1.3291 - 58ms/epoch - 4ms/step
# Epoch 4/100
# 14/14 - 0s - loss: 0.6717 - val_loss: 0.4371 - 55ms/epoch - 4ms/step
# Epoch 5/100
# 14/14 - 0s - loss: 0.3251 - val_loss: 0.1707 - 55ms/epoch - 4ms/step
# Epoch 6/100
# 14/14 - 0s - loss: 0.2527 - val_loss: 0.1502 - 58ms/epoch - 4ms/step
# Epoch 7/100
# 14/14 - 0s - loss: 0.2169 - val_loss: 0.1460 - 57ms/epoch - 4ms/step
# Epoch 8/100
# 14/14 - 0s - loss: 0.2130 - val_loss: 0.1424 - 56ms/epoch - 4ms/step
# Epoch 9/100
# 14/14 - 0s - loss: 0.2082 - val_loss: 0.1388 - 54ms/epoch - 4ms/step
# Epoch 10/100
# 14/14 - 0s - loss: 0.2050 - val_loss: 0.1364 - 57ms/epoch - 4ms/step
# Epoch 11/100
# 14/14 - 0s - loss: 0.2031 - val_loss: 0.1388 - 58ms/epoch - 4ms/step
# Epoch 12/100
# 14/14 - 0s - loss: 0.2059 - val_loss: 0.1359 - 56ms/epoch - 4ms/step
# Epoch 13/100
# 14/14 - 0s - loss: 0.2195 - val_loss: 0.1702 - 55ms/epoch - 4ms/step
# Epoch 14/100
# 14/14 - 0s - loss: 0.2092 - val_loss: 0.1343 - 58ms/epoch - 4ms/step
# Epoch 15/100
# 14/14 - 0s - loss: 0.2100 - val_loss: 0.1631 - 56ms/epoch - 4ms/step
# Epoch 16/100
# 14/14 - 0s - loss: 0.2019 - val_loss: 0.1465 - 55ms/epoch - 4ms/step
# Epoch 17/100
# 14/14 - 0s - loss: 0.2051 - val_loss: 0.1356 - 55ms/epoch - 4ms/step
# Epoch 18/100
# 14/14 - 0s - loss: 0.2070 - val_loss: 0.1434 - 55ms/epoch - 4ms/step
# Epoch 19/100
# 14/14 - 0s - loss: 0.2030 - val_loss: 0.1389 - 56ms/epoch - 4ms/step
# Epoch 19: early stopping
# 4
# Epoch 1/100
# 14/14 - 1s - loss: 86.2158 - val_loss: 58.6182 - 929ms/epoch - 66ms/step
# Epoch 2/100
# 14/14 - 0s - loss: 39.7459 - val_loss: 12.6619 - 58ms/epoch - 4ms/step
# Epoch 3/100
# 14/14 - 0s - loss: 5.4600 - val_loss: 3.9247 - 57ms/epoch - 4ms/step
# Epoch 4/100
# 14/14 - 0s - loss: 3.6166 - val_loss: 0.8391 - 58ms/epoch - 4ms/step
# Epoch 5/100
# 14/14 - 0s - loss: 1.9121 - val_loss: 0.6079 - 57ms/epoch - 4ms/step
# Epoch 6/100
# 14/14 - 0s - loss: 1.6342 - val_loss: 0.6818 - 59ms/epoch - 4ms/step
# Epoch 7/100
# 14/14 - 0s - loss: 1.4693 - val_loss: 0.5917 - 59ms/epoch - 4ms/step
# Epoch 8/100
# 14/14 - 0s - loss: 1.3925 - val_loss: 0.5864 - 59ms/epoch - 4ms/step
# Epoch 9/100
# 14/14 - 0s - loss: 1.3676 - val_loss: 0.5972 - 58ms/epoch - 4ms/step
# Epoch 10/100
# 14/14 - 0s - loss: 1.4375 - val_loss: 0.5617 - 56ms/epoch - 4ms/step
# Epoch 11/100
# 14/14 - 0s - loss: 1.2381 - val_loss: 0.5526 - 57ms/epoch - 4ms/step
# Epoch 12/100
# 14/14 - 0s - loss: 1.2342 - val_loss: 0.5683 - 56ms/epoch - 4ms/step
# Epoch 13/100
# 14/14 - 0s - loss: 1.1670 - val_loss: 0.5134 - 56ms/epoch - 4ms/step
# Epoch 14/100
# 14/14 - 0s - loss: 1.1474 - val_loss: 0.5291 - 54ms/epoch - 4ms/step
# Epoch 15/100
# 14/14 - 0s - loss: 1.2135 - val_loss: 0.5228 - 55ms/epoch - 4ms/step
# Epoch 16/100
# 14/14 - 0s - loss: 1.1455 - val_loss: 0.5419 - 57ms/epoch - 4ms/step
# Epoch 17/100
# 14/14 - 0s - loss: 1.1182 - val_loss: 0.5389 - 56ms/epoch - 4ms/step
# Epoch 18/100
# 14/14 - 0s - loss: 1.2801 - val_loss: 0.5660 - 55ms/epoch - 4ms/step
# Epoch 18: early stopping
# Training finished...Loading the best model
#
# 5/5 [==============================] - 0s 2ms/step
# Final accuracy: 0.9440559440559441

# %% [markdown]
# ### Confusion Matrix
#
# The confusion matrix is a common visualization for both binary and multi-class classification problems.  The following code generates a confusion matrix:

# %%
import numpy as np

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# Compute confusion matrix
cm = confusion_matrix(y_true, pred)
print(cm)


print('Plotting confusion matrix')

plt.figure()
plot_confusion_matrix(cm, diagnosis)
plt.show()

print(classification_report(y_true, pred))
# Out:
# [[88  1]
#  [ 4 50]]
# Plotting confusion matrix
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97        89
#            1       0.98      0.93      0.95        54
#
#     accuracy                           0.97       143
#    macro avg       0.97      0.96      0.96       143
# weighted avg       0.97      0.97      0.96       143

# %% [markdown]
# ### ROC Curves
#
# **An ROC curve measures how good a model is regardless of the cutoff.**
#
# The following code shows an ROC chart for the breast cancer neural network.  The area under the curve (AUC) is also an important measure.  The larger the AUC, the better.

# %%
pred = model.predict(x_test)
pred = pred[:,1] # Only positive class (M)
plot_roc(pred,y_true)
# Out:
# 5/5 [==============================] - 0s 2ms/step

# %% [markdown]
# # Visualizing multi-class classification models
#
# We've already seen multi-class classification, with the iris dataset.  Confusion matrixes work just fine with 3 classes.  The following code generates a confusion matrix for iris.

# %%
import pandas as pd
import io
import requests
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn import metrics
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint

path = "./data/"
    
filename = os.path.join(path,"iris.csv")    
df = pd.read_csv(filename,na_values=['NA','?'])

species = encode_text_index(df,"species")
x,y = to_xy(df,"species")

# Split into train/test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

model = Sequential()
model.add(Dense(20, input_dim=x.shape[1], activation='relu'))
model.add(Dense(10))
model.add(Dense(y.shape[1],activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam')

monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, verbose=0, mode='auto')
checkpointer = ModelCheckpoint(filepath="dnn/best_weights.hdf5", verbose=0, save_best_only=True) # save best model

model.fit(x_train,y_train,validation_data=(x_test,y_test),callbacks=[monitor,checkpointer],verbose=2,epochs=100)

model.load_weights('dnn/best_weights.hdf5') # load weights from best model
# Out:
# Epoch 1/100
# 4/4 - 1s - loss: 2.4078 - val_loss: 1.9723 - 1s/epoch - 316ms/step
# Epoch 2/100
# 4/4 - 0s - loss: 2.1031 - val_loss: 1.7468 - 75ms/epoch - 19ms/step
# Epoch 3/100
# 4/4 - 0s - loss: 1.8551 - val_loss: 1.5737 - 74ms/epoch - 18ms/step
# Epoch 4/100
# 4/4 - 0s - loss: 1.6617 - val_loss: 1.4432 - 101ms/epoch - 25ms/step
# Epoch 5/100
# 4/4 - 0s - loss: 1.5133 - val_loss: 1.3362 - 88ms/epoch - 22ms/step
# Epoch 6/100
# 4/4 - 0s - loss: 1.3820 - val_loss: 1.2476 - 89ms/epoch - 22ms/step
# Epoch 7/100
# 4/4 - 0s - loss: 1.2709 - val_loss: 1.1744 - 100ms/epoch - 25ms/step
# Epoch 8/100
# 4/4 - 0s - loss: 1.1813 - val_loss: 1.1172 - 90ms/epoch - 23ms/step
# Epoch 9/100
# 4/4 - 0s - loss: 1.1168 - val_loss: 1.0757 - 88ms/epoch - 22ms/step
# Epoch 10/100
# 4/4 - 0s - loss: 1.0668 - val_loss: 1.0478 - 85ms/epoch - 21ms/step
# Epoch 11/100
# 4/4 - 0s - loss: 1.0340 - val_loss: 1.0297 - 88ms/epoch - 22ms/step
# Epoch 12/100
# 4/4 - 0s - loss: 1.0081 - val_loss: 1.0138 - 77ms/epoch - 19ms/step
# Epoch 13/100
# 4/4 - 0s - loss: 0.9902 - val_loss: 0.9978 - 75ms/epoch - 19ms/step
# Epoch 14/100
# 4/4 - 0s - loss: 0.9723 - val_loss: 0.9807 - 74ms/epoch - 19ms/step
# Epoch 15/100
# 4/4 - 0s - loss: 0.9537 - val_loss: 0.9600 - 80ms/epoch - 20ms/step
# Epoch 16/100
# 4/4 - 0s - loss: 0.9354 - val_loss: 0.9378 - 72ms/epoch - 18ms/step
# Epoch 17/100
# 4/4 - 0s - loss: 0.9160 - val_loss: 0.9175 - 72ms/epoch - 18ms/step
# Epoch 18/100
# 4/4 - 0s - loss: 0.8987 - val_loss: 0.8950 - 73ms/epoch - 18ms/step
# Epoch 19/100
# 4/4 - 0s - loss: 0.8814 - val_loss: 0.8746 - 72ms/epoch - 18ms/step
# Epoch 20/100
# 4/4 - 0s - loss: 0.8654 - val_loss: 0.8549 - 73ms/epoch - 18ms/step
# Epoch 21/100
# 4/4 - 0s - loss: 0.8494 - val_loss: 0.8350 - 71ms/epoch - 18ms/step
# Epoch 22/100
# 4/4 - 0s - loss: 0.8321 - val_loss: 0.8162 - 73ms/epoch - 18ms/step
# Epoch 23/100
# 4/4 - 0s - loss: 0.8156 - val_loss: 0.7977 - 71ms/epoch - 18ms/step
# Epoch 24/100
# 4/4 - 0s - loss: 0.7996 - val_loss: 0.7793 - 76ms/epoch - 19ms/step
# Epoch 25/100
# 4/4 - 0s - loss: 0.7833 - val_loss: 0.7594 - 85ms/epoch - 21ms/step
# Epoch 26/100
# 4/4 - 0s - loss: 0.7671 - val_loss: 0.7413 - 98ms/epoch - 25ms/step
# Epoch 27/100
# 4/4 - 0s - loss: 0.7536 - val_loss: 0.7229 - 101ms/epoch - 25ms/step
# Epoch 28/100
# 4/4 - 0s - loss: 0.7364 - val_loss: 0.7066 - 94ms/epoch - 23ms/step
# Epoch 29/100
# 4/4 - 0s - loss: 0.7212 - val_loss: 0.6908 - 100ms/epoch - 25ms/step
# Epoch 30/100
# 4/4 - 0s - loss: 0.7064 - val_loss: 0.6752 - 114ms/epoch - 28ms/step
# Epoch 31/100
# 4/4 - 0s - loss: 0.6920 - val_loss: 0.6605 - 99ms/epoch - 25ms/step
# Epoch 32/100
# 4/4 - 0s - loss: 0.6774 - val_loss: 0.6456 - 78ms/epoch - 19ms/step
# Epoch 33/100
# 4/4 - 0s - loss: 0.6634 - val_loss: 0.6309 - 81ms/epoch - 20ms/step
# Epoch 34/100
# 4/4 - 0s - loss: 0.6503 - val_loss: 0.6167 - 77ms/epoch - 19ms/step
# Epoch 35/100
# 4/4 - 0s - loss: 0.6369 - val_loss: 0.6021 - 79ms/epoch - 20ms/step
# Epoch 36/100
# 4/4 - 0s - loss: 0.6242 - val_loss: 0.5872 - 76ms/epoch - 19ms/step
# Epoch 37/100
# 4/4 - 0s - loss: 0.6112 - val_loss: 0.5733 - 75ms/epoch - 19ms/step
# Epoch 38/100
# 4/4 - 0s - loss: 0.5996 - val_loss: 0.5604 - 79ms/epoch - 20ms/step
# Epoch 39/100
# 4/4 - 0s - loss: 0.5882 - val_loss: 0.5487 - 77ms/epoch - 19ms/step
# Epoch 40/100
# 4/4 - 0s - loss: 0.5770 - val_loss: 0.5361 - 80ms/epoch - 20ms/step
# Epoch 41/100
# 4/4 - 0s - loss: 0.5652 - val_loss: 0.5249 - 75ms/epoch - 19ms/step
# Epoch 42/100
# 4/4 - 0s - loss: 0.5552 - val_loss: 0.5149 - 82ms/epoch - 21ms/step
# Epoch 43/100
# 4/4 - 0s - loss: 0.5449 - val_loss: 0.5042 - 84ms/epoch - 21ms/step
# Epoch 44/100
# 4/4 - 0s - loss: 0.5353 - val_loss: 0.4942 - 79ms/epoch - 20ms/step
# Epoch 45/100
# 4/4 - 0s - loss: 0.5248 - val_loss: 0.4838 - 75ms/epoch - 19ms/step
# Epoch 46/100
# 4/4 - 0s - loss: 0.5158 - val_loss: 0.4740 - 76ms/epoch - 19ms/step
# Epoch 47/100
# 4/4 - 0s - loss: 0.5068 - val_loss: 0.4649 - 78ms/epoch - 19ms/step
# Epoch 48/100
# 4/4 - 0s - loss: 0.4975 - val_loss: 0.4565 - 73ms/epoch - 18ms/step
# Epoch 49/100
# 4/4 - 0s - loss: 0.4887 - val_loss: 0.4485 - 74ms/epoch - 18ms/step
# Epoch 50/100
# 4/4 - 0s - loss: 0.4801 - val_loss: 0.4398 - 74ms/epoch - 19ms/step
# Epoch 51/100
# 4/4 - 0s - loss: 0.4721 - val_loss: 0.4315 - 75ms/epoch - 19ms/step
# Epoch 52/100
# 4/4 - 0s - loss: 0.4640 - val_loss: 0.4238 - 77ms/epoch - 19ms/step
# Epoch 53/100
# 4/4 - 0s - loss: 0.4563 - val_loss: 0.4156 - 75ms/epoch - 19ms/step
# Epoch 54/100
# 4/4 - 0s - loss: 0.4487 - val_loss: 0.4076 - 74ms/epoch - 19ms/step
# Epoch 55/100
# 4/4 - 0s - loss: 0.4412 - val_loss: 0.4001 - 73ms/epoch - 18ms/step
# Epoch 56/100
# 4/4 - 0s - loss: 0.4338 - val_loss: 0.3921 - 72ms/epoch - 18ms/step
# Epoch 57/100
# 4/4 - 0s - loss: 0.4267 - val_loss: 0.3853 - 78ms/epoch - 19ms/step
# Epoch 58/100
# 4/4 - 0s - loss: 0.4196 - val_loss: 0.3786 - 74ms/epoch - 18ms/step
# Epoch 59/100
# 4/4 - 0s - loss: 0.4127 - val_loss: 0.3718 - 73ms/epoch - 18ms/step
# Epoch 60/100
# 4/4 - 0s - loss: 0.4063 - val_loss: 0.3644 - 74ms/epoch - 19ms/step
# Epoch 61/100
# 4/4 - 0s - loss: 0.4000 - val_loss: 0.3580 - 72ms/epoch - 18ms/step
# Epoch 62/100
# 4/4 - 0s - loss: 0.3934 - val_loss: 0.3518 - 75ms/epoch - 19ms/step
# Epoch 63/100
# 4/4 - 0s - loss: 0.3871 - val_loss: 0.3460 - 77ms/epoch - 19ms/step
# Epoch 64/100
# 4/4 - 0s - loss: 0.3817 - val_loss: 0.3408 - 73ms/epoch - 18ms/step
# Epoch 65/100
# 4/4 - 0s - loss: 0.3751 - val_loss: 0.3345 - 74ms/epoch - 18ms/step
# Epoch 66/100
# 4/4 - 0s - loss: 0.3694 - val_loss: 0.3285 - 76ms/epoch - 19ms/step
# Epoch 67/100
# 4/4 - 0s - loss: 0.3636 - val_loss: 0.3232 - 107ms/epoch - 27ms/step
# Epoch 68/100
# 4/4 - 0s - loss: 0.3579 - val_loss: 0.3177 - 105ms/epoch - 26ms/step
# Epoch 69/100
# 4/4 - 0s - loss: 0.3525 - val_loss: 0.3126 - 75ms/epoch - 19ms/step
# Epoch 70/100
# 4/4 - 0s - loss: 0.3473 - val_loss: 0.3078 - 75ms/epoch - 19ms/step
# Epoch 71/100
# 4/4 - 0s - loss: 0.3421 - val_loss: 0.3024 - 75ms/epoch - 19ms/step
# Epoch 72/100
# 4/4 - 0s - loss: 0.3369 - val_loss: 0.2972 - 82ms/epoch - 20ms/step
# Epoch 73/100
# 4/4 - 0s - loss: 0.3323 - val_loss: 0.2932 - 75ms/epoch - 19ms/step
# Epoch 74/100
# 4/4 - 0s - loss: 0.3270 - val_loss: 0.2881 - 73ms/epoch - 18ms/step
# Epoch 75/100
# 4/4 - 0s - loss: 0.3221 - val_loss: 0.2832 - 75ms/epoch - 19ms/step
# Epoch 76/100
# 4/4 - 0s - loss: 0.3174 - val_loss: 0.2785 - 76ms/epoch - 19ms/step
# Epoch 77/100
# 4/4 - 0s - loss: 0.3128 - val_loss: 0.2739 - 73ms/epoch - 18ms/step
# Epoch 78/100
# 4/4 - 0s - loss: 0.3087 - val_loss: 0.2696 - 74ms/epoch - 18ms/step
# Epoch 79/100
# 4/4 - 0s - loss: 0.3038 - val_loss: 0.2662 - 76ms/epoch - 19ms/step
# Epoch 80/100
# 4/4 - 0s - loss: 0.2997 - val_loss: 0.2627 - 72ms/epoch - 18ms/step
# Epoch 81/100
# 4/4 - 0s - loss: 0.2954 - val_loss: 0.2581 - 75ms/epoch - 19ms/step
# Epoch 82/100
# 4/4 - 0s - loss: 0.2909 - val_loss: 0.2539 - 74ms/epoch - 18ms/step
# Epoch 83/100
# 4/4 - 0s - loss: 0.2868 - val_loss: 0.2499 - 74ms/epoch - 18ms/step
# Epoch 84/100
# 4/4 - 0s - loss: 0.2836 - val_loss: 0.2459 - 73ms/epoch - 18ms/step
# Epoch 85/100
# 4/4 - 0s - loss: 0.2790 - val_loss: 0.2426 - 74ms/epoch - 19ms/step
# Epoch 86/100
# 4/4 - 0s - loss: 0.2749 - val_loss: 0.2393 - 73ms/epoch - 18ms/step
# Epoch 87/100
# 4/4 - 0s - loss: 0.2718 - val_loss: 0.2363 - 75ms/epoch - 19ms/step
# Epoch 88/100
# 4/4 - 0s - loss: 0.2683 - val_loss: 0.2317 - 73ms/epoch - 18ms/step
# Epoch 89/100
# 4/4 - 0s - loss: 0.2643 - val_loss: 0.2281 - 81ms/epoch - 20ms/step
# Epoch 90/100
# 4/4 - 0s - loss: 0.2611 - val_loss: 0.2257 - 75ms/epoch - 19ms/step
# Epoch 91/100
# 4/4 - 0s - loss: 0.2570 - val_loss: 0.2222 - 127ms/epoch - 32ms/step
# Epoch 92/100
# 4/4 - 0s - loss: 0.2541 - val_loss: 0.2194 - 80ms/epoch - 20ms/step
# Epoch 93/100
# 4/4 - 0s - loss: 0.2501 - val_loss: 0.2151 - 80ms/epoch - 20ms/step
# Epoch 94/100
# 4/4 - 0s - loss: 0.2469 - val_loss: 0.2116 - 83ms/epoch - 21ms/step
# Epoch 95/100
# 4/4 - 0s - loss: 0.2444 - val_loss: 0.2084 - 81ms/epoch - 20ms/step
# Epoch 96/100
# 4/4 - 0s - loss: 0.2420 - val_loss: 0.2058 - 73ms/epoch - 18ms/step
# Epoch 97/100
# 4/4 - 0s - loss: 0.2374 - val_loss: 0.2029 - 75ms/epoch - 19ms/step
# Epoch 98/100
# 4/4 - 0s - loss: 0.2345 - val_loss: 0.2008 - 73ms/epoch - 18ms/step
# Epoch 99/100
# 4/4 - 0s - loss: 0.2316 - val_loss: 0.1984 - 75ms/epoch - 19ms/step
# Epoch 100/100
# 4/4 - 0s - loss: 0.2283 - val_loss: 0.1956 - 73ms/epoch - 18ms/step

# %%
import numpy as np

from sklearn import svm, datasets
from sklearn.metrics import confusion_matrix, classification_report

pred = model.predict(x_test)
pred = np.argmax(pred,axis=1)
y_true = np.argmax(y_test,axis=1)
    
# Compute confusion matrix
cm = confusion_matrix(y_true, pred)
print(cm)

print('Ploting confusion matrix')
plt.figure()
plot_confusion_matrix(cm, species)
plt.show()


print(classification_report(y_true, pred))
# Out:
# 2/2 [==============================] - 0s 2ms/step
# [[15  0  0]
#  [ 0 11  0]
#  [ 0  0 12]]
# Ploting confusion matrix
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      1.00      1.00        11
#            2       1.00      1.00      1.00        12
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38

# %% [markdown]
# # Visualizing regression models
#
# We've already seen regression with the MPG dataset.  Regression uses its own set of visualizations, one of the most common is the lift chart.  The following code generates a lift chart.

# %%
# %matplotlib inline
from matplotlib.pyplot import figure, show
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from sklearn import metrics
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint


path = "./data/"
preprocess = False

filename_read = os.path.join(path,"auto-mpg.csv")
df = pd.read_csv(filename_read,na_values=['NA','?'])

# create feature vector
missing_median(df, 'horsepower')
encode_text_dummy(df, 'origin')
df.drop('name',1,inplace=True)
if preprocess:
    encode_numeric_zscore(df, 'horsepower')
    encode_numeric_zscore(df, 'weight')
    encode_numeric_zscore(df, 'cylinders')
    encode_numeric_zscore(df, 'displacement')
    encode_numeric_zscore(df, 'acceleration')
    encode_numeric_zscore(df, 'year')

# Encode to a 2D matrix for training
x,y = to_xy(df,'mpg')

# Split into train/test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

model = Sequential()
model.add(Dense(100, input_dim=x.shape[1], activation='relu'))      # try changing 100 to 10
model.add(Dense(10, activation='relu'))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')

monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, verbose=1, mode='auto')

checkpointer = ModelCheckpoint(filepath="dnn/best_weights.hdf5", verbose=0, save_best_only=True) # save best model

model.fit(x_train,y_train,validation_data=(x_test,y_test),callbacks=[monitor,checkpointer],verbose=2,epochs=500)

model.load_weights('dnn/best_weights.hdf5') # load weights from best model

# Predict and measure RMSE
pred = model.predict(x_test)

score = np.sqrt(metrics.mean_squared_error(pred,y_test))
print("Score (RMSE): {}".format(score))

# Plot the chart
chart_regression(pred.flatten(),y_test, sort=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 23
#      21 missing_median(df, 'horsepower')
#      22 encode_text_dummy(df, 'origin')
# ---> 23 df.drop('name',1,inplace=True)
#      24 if preprocess:
#      25     encode_numeric_zscore(df, 'horsepower')
#
# TypeError: DataFrame.drop() takes from 1 to 2 positional arguments but 3 positional arguments (and 1 keyword-only argument) were given

# %% [markdown]
# The lift chart as shown above was achieved by performing the following actions:
#
# * Sort the data by expected output.  Plot the blue line above.  Blue line is always increasing.
# * For every point on the x-axis plot the predicted value for that same data point.  This is the orange line above.
# * The x-axis is the index of test data after sorting.  The index always starts low and ends high.
#
# Reading a lift chart:
# * The expected and predict lines should be close.  Notice where one is above the other.
# * The above chart is the most accurate on lower MPG.

# %% [markdown]
# #### Regression lift chart without sorting on expected output (y_test)

# %%
chart_regression(pred.flatten(),y_test,sort=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 chart_regression(pred.flatten(),y_test,sort=False)
#
# Cell In[3], line 77, in chart_regression(pred, y, sort)
#      76 def chart_regression(pred,y,sort=True):
# ---> 77     t = pd.DataFrame({'pred' : pred, 'y' : y.flatten()})
#      78     if sort:
#      79         t.sort_values(by=['y'],inplace=True)
#
# File /opt/anaconda3/envs/myenv/lib/python3.11/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File /opt/anaconda3/envs/myenv/lib/python3.11/site-packages/pandas/core/internals/construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File /opt/anaconda3/envs/myenv/lib/python3.11/site-packages/pandas/core/internals/construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File /opt/anaconda3/envs/myenv/lib/python3.11/site-packages/pandas/core/internals/construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length

# %% [markdown]
# ### References:
#
# * [Google Colab](https://colab.research.google.com/) - Free web based platform that includes Python, Juypter Notebooks, and TensorFlow with free GPU support.  No setup needed.
# * [IBM Cognitive Class Labs](https://www.datascientistworkbench.com) - Free web based platform that includes Python, Juypter Notebooks, and TensorFlow.  No setup needed.
# * [Python Anaconda](https://www.continuum.io/downloads) - Python distribution that includes many data science packages, such as Numpy, Scipy, Scikit-Learn, Pandas, and much more.
# * [TensorFlow](https://www.tensorflow.org/) - Google's mathematics package for deep learning.
# * [Kaggle](https://www.kaggle.com/) - Competitive data science.  Good source of sample data.
# * T81-558: Applications of Deep Neural Networks. Instructor: [Jeff Heaton](https://sites.wustl.edu/jeffheaton/)
